# %%
import pandas as pd
loan = pd.read_csv("loan.csv")
print(loan.head())
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
loan.shape
# Out:
# (39717, 111)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
loan.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
#remove the customers in the list who are under Charged Off 
loan1 = loan
loan1 = loan1[~(loan1.loan_status=="Charged Off")]
loan1.shape
# Out:
# (34090, 111)

# %%
#remove all null values
loan1.isnull().sum()
loan1 = loan1[~loan1.isnull()]
loan1.shape
# Out:
# (34090, 111)

# %%
#it is observed that customers whose annual_inc less than 400000 are fully paid customers.
loan1 = loan1[~(loan1.annual_inc > 400000)]
loan1.shape
loan1 = loan1[~(loan1.loan_status=="Current")]
loan1.shape
# Out:
# (32872, 111)

# %%
"""sanity checks - 
1. Income per month should be more than the interest of the loan
2. total payment paid for loan should be more than the payment approved
"""
loan1.annual_inc = loan1.annual_inc.astype("int32")
#first sanity check is clear
loan1[(loan1.annual_inc >= loan1.loan_amnt)].shape
#second sanity check
loan1 = loan1[~(loan1.total_pymnt < loan1.loan_amnt)]
loan1.shape
# Out:
# (31674, 111)

# %%
loan1.head(20)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0   1077501    1296599       5000         5000       4975.00000   36 months
# 2   1077175    1313524       2400         2400       2400.00000   36 months
# 3   1076863    1277178      10000        10000      10000.00000   36 months
# 5   1075269    1311441       5000         5000       5000.00000   36 months
# 6   1069639    1304742       7000         7000       7000.00000   60 months
# 7   1072053    1288686       3000         3000       3000.00000   36 months
# 10  1070078    1305201       6500         6500       6500.00000   60 months
# 11  1069908    1305008      12000        12000      12000.00000   36 months
# 13  1069866    1304956       3000         3000       3000.00000   36 months
# 15  1069759    1304871       1000         1000       1000.00000   36 months
# 16  1065775    1299699      10000        10000      10000.00000   36 months
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(loan1.loan_amnt)
plt.title("Finding junk values using boxplot for loan_amnt")
plt.ylabel("loan amount")
plt.show()

#remove junk values --> loan_amnt > 30000
loan1[(loan1.loan_amnt>30000)].shape
# Out:
# (474, 111)
